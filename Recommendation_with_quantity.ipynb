# %%
df = pd.read_csv('combined.csv')

df.head()
# Out:
#   orderNumber        asin
# 0   93f35a6b9  B00007GDFV
# 1   d6ffc1262  B00007GDFV
# 2   b52b6a408  B00007GDFV
# 3   d6eba872b  B00007GDFV
# 4   87e6fdc25  B00007GDFV

# %%
import pandas as pd
import numpy as np

# Define the weights for the quantities (adjust these weights as needed)
weights = [0.6, 0.3, 0.1]

# Generate random quantities based on the weights
random_quantities = np.random.choice([1, 2, 3], size=len(df), p=weights)

# Add the new 'quantity' column to the DataFrame
df['quantity'] = random_quantities


df.head()
# Out:
#   orderNumber        asin  quantity
# 0   93f35a6b9  B00007GDFV         2
# 1   d6ffc1262  B00007GDFV         2
# 2   b52b6a408  B00007GDFV         2
# 3   d6eba872b  B00007GDFV         1
# 4   87e6fdc25  B00007GDFV         2

# %%
df[:20]
# Out:
#    orderNumber        asin  quantity
# 0    93f35a6b9  B00007GDFV         2
# 1    d6ffc1262  B00007GDFV         2
# 2    b52b6a408  B00007GDFV         2
# 3    d6eba872b  B00007GDFV         1
# 4    87e6fdc25  B00007GDFV         2
# 5    8fa8fa19c  B00007GDFV         3
# 6    d83868835  B00007GDFV         2
# 7    381bfd09c  B00007GDFV         1
# 8    f64d4d6bc  B00007GDFV         1
# 9    e2efe6ffc  B00007GDFV         1
# 10   541fe95b3  B00007GDFV         1
# 11   d2dbe3364  B00007GDFV         2
# 12   6f8debef8  B00007GDFV         1
# 13   2b431322d  B00007GDFV         1
# 14   e6c6a6bd4  B00007GDFV         1
# 15   f1127065c  B00007GDFV         3
# 16   f22f697fa  B00007GDFV         1
# 17   b251153a9  B00007GDFV         1
# 18   66f60db65  B00007GDFV         1
# 19   50c599327  B00007GDFV         2

# %%
# Create a pivot table
pivot_df = df.pivot_table(index='asin', columns='orderNumber', values='quantity', aggfunc='sum', fill_value=0)
# Out:
# <ipython-input-7-11e2502b7bf4>:2: PerformanceWarning: The following operation may generate 2824289229 cells in the resulting pandas object.
#   pivot_df = df.pivot_table(index='asin', columns='orderNumber', values='quantity', aggfunc='sum', fill_value=0)
